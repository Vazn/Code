# %%
x, y = var('x y')
plot_xrange = (x, -10, 10)
plot_yrange = (y, -10, 10)

customColors = ["firebrick", "darkslateblue", "goldenrod", "olivedrab", "darkorange", "mediumpurple"]

p1 = plot([sin], plot_xrange, color = "steelblue", legend_label='automatic')
p1 += plot([x*exp(-n*x^2) for n in [1..8]], plot_xrange, fill={i:[i-1] for i in [1..4]}, color = customColors, legend_label='automatic')

show(p1, xmin=-2, xmax=2, ymin=-0.7, ymax=0.7, figsize=10)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 13 graphics primitives
